# %%
import pandas as pd
import random as rd
import numpy as np

# %%
df = pd.read_csv("example.csv")

# %%
df
# Out:
#        Unnamed: 0  Safety    yacEPA  Drive  FieldGoalDistance    airEPA  \
# 0          244485       0  1.240299     18                NaN -0.588101
# 1          115340       0       NaN     22                NaN       NaN
# 2           68357       0       NaN      8                NaN       NaN
# 3          368377       0  1.075660     24                NaN  0.402080
# 4          384684       0       NaN     11                NaN       NaN
# ...           ...     ...       ...    ...                ...       ...
# 40764       79438       0       NaN      3                NaN       NaN
# 40765      398233       0       NaN      9                NaN       NaN
# 40766      396466       0       NaN      8                NaN       NaN
# 40767      333861       0  0.025040     14                NaN  0.280049
# 40768      247608       0 -2.441755      6                NaN  1.692283
#
#        Field_Goal_Prob posteam  Penalty.Yards FieldGoalResult  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# FieldGoalDistance              39867
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# FieldGoalResult                39861
# DefTeamScore                    2750
# Tackler2                       35826
# Away_WP_pre                     2546
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                          27
# Passer                         24073
# Touchdown                          0
# TwoPointConv                   40716
# PassOutcome                    24018
# PlayTimeDiff                      43
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# ...

# %%
df.shape
# Out:
# (40769, 32)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Safety', 'yacEPA', 'Drive', 'FieldGoalDistance',
#        'airEPA', 'Field_Goal_Prob', 'posteam', 'Penalty.Yards',
#        'FieldGoalResult', 'DefTeamScore', 'Tackler2', 'Away_WP_pre',
#        'Timeout_Indicator', 'ydsnet', 'TimeSecs', 'Passer', 'Touchdown',
#        'TwoPointConv', 'PassOutcome', 'PlayTimeDiff', 'RushAttempt',
#        'Accepted.Penalty', 'qtr', 'AwayTimeouts_Remaining_Post', 'RunGap',
#        'Reception', 'TimeUnder', 'Season', 'Opp_Safety_Prob', 'No_Score_Prob',
#        'Challenge.Replay'],
#       dtype='object')

# %%
df['No_Score_Prob'] = df['No_Score_Prob'].fillna(value=df['No_Score_Prob'].median())
# df['No_Score_Prob']
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# FieldGoalDistance              39867
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# FieldGoalResult                39861
# DefTeamScore                    2750
# Tackler2                       35826
# Away_WP_pre                     2546
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                          27
# Passer                         24073
# Touchdown                          0
# TwoPointConv                   40716
# PassOutcome                    24018
# PlayTimeDiff                      43
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# ...

# %%
df['Opp_Safety_Prob'] = df['Opp_Safety_Prob'].fillna(value=df['Opp_Safety_Prob'].median())
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# FieldGoalDistance              39867
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# FieldGoalResult                39861
# DefTeamScore                    2750
# Tackler2                       35826
# Away_WP_pre                     2546
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                          27
# Passer                         24073
# Touchdown                          0
# TwoPointConv                   40716
# PassOutcome                    24018
# PlayTimeDiff                      43
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# ...

# %%
df['PlayTimeDiff']
# Out:
# 0        12.0
# 1        44.0
# 2         0.0
# 3         8.0
# 4         0.0
#          ...
# 40764    31.0
# 40765    20.0
# 40766    27.0
# 40767     7.0
# 40768     5.0
# Name: PlayTimeDiff, Length: 40769, dtype: float64

# %%
print(df['PlayTimeDiff'].mean())
print(df['PlayTimeDiff'].median())
print(df['PlayTimeDiff'].min())
print(df['PlayTimeDiff'].max())
# Out:
# 20.77422285517851
# 18.0
# 0.0
# 927.0

# %%
df['PlayTimeDiff']= df['PlayTimeDiff'].fillna(value=df['PlayTimeDiff'].median())

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# FieldGoalDistance              39867
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# FieldGoalResult                39861
# DefTeamScore                    2750
# Tackler2                       35826
# Away_WP_pre                     2546
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                          27
# Passer                         24073
# Touchdown                          0
# TwoPointConv                   40716
# PassOutcome                    24018
# PlayTimeDiff                       0
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# ...

# %%
df['PassOutcome']
# Out:
# 0               Complete
# 1                    NaN
# 2                    NaN
# 3               Complete
# 4                    NaN
#               ...
# 40764                NaN
# 40765                NaN
# 40766                NaN
# 40767           Complete
# 40768    Incomplete Pass
# Name: PassOutcome, Length: 40769, dtype: object

# %%
print(df['PassOutcome'].value_counts())
print(df['PassOutcome'].isnull().sum())
# Out:
# PassOutcome
# Complete           10122
# Incomplete Pass     6629
# Name: count, dtype: int64
# 24018

# %% [markdown]
# ## PassOutcome ustunidagi valuelarni hamda NAn qiymatlarni sanab oldim

# %%
df['PassOutcome'] = df['PassOutcome'].fillna(value='-1')

# %% [markdown]
# ## ikki hil javob bor Complete , Incomplete pass va NaN qiymatlar ikkisiining yigindisidan ham oshib ketadi shuning uchun men NAN qiymatlar orniga ikkisidan birini qoyishuim juda katta xatolik boladi deb oyladim va malumot berilmagani uchun NAN qiymatlar orniga missin indiktor qilib ushbu ustunda umuman uchramydigan -1 ni qoyib ketdim

# %%
print(df['PassOutcome'].value_counts())
print(df['PassOutcome'].isnull().sum())
# Out:
# PassOutcome
# -1                 24018
# Complete           10122
# Incomplete Pass     6629
# Name: count, dtype: int64
# 0

# %% [markdown]
# ## va buyerda qilgan ishimni tekshirdim

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# FieldGoalDistance              39867
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# FieldGoalResult                39861
# DefTeamScore                    2750
# Tackler2                       35826
# Away_WP_pre                     2546
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                          27
# Passer                         24073
# Touchdown                          0
# TwoPointConv                   40716
# PassOutcome                        0
# PlayTimeDiff                       0
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# ...

# %% [markdown]
# ## tekshirish uchun

# %%
print(df['TwoPointConv'].value_counts())
print(df['TwoPointConv'].isnull().sum())
# Out:
# TwoPointConv
# Failure    28
# Success    25
# Name: count, dtype: int64
# 40716

# %% [markdown]
# ## bu yerda ham shu holat kuzatilmoqda

# %%
df['TwoPointConv'] = df['TwoPointConv'].fillna(value='-1')

# %%
print(df['TwoPointConv'].value_counts())
print(df['TwoPointConv'].isnull().sum())
print(df.isnull().sum())
# Out:
# TwoPointConv
# -1         40716
# Failure       28
# Success       25
# Name: count, dtype: int64
# 0
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# FieldGoalDistance              39867
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# FieldGoalResult                39861
# DefTeamScore                    2750
# Tackler2                       35826
# Away_WP_pre                     2546
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                          27
# Passer                         24073
# Touchdown                          0
# TwoPointConv                       0
# PassOutcome                        0
# PlayTimeDiff                       0
# RushAttempt                        0
# ...

# %% [markdown]
# ## menda yana tepadagi holat yuz berdi va men yana shunday ishni amalga oshirdim

# %%
print(df['Passer'].value_counts())
print(df['Passer'].isnull().sum())
# Out:
# Passer
# D.Brees         577
# E.Manning       541
# M.Stafford      534
# T.Brady         523
# P.Rivers        514
#                ...
# C.Cook            1
# M.Koenen          1
# A.Brown           1
# L.Fitzgerald      1
# J.Callahan        1
# Name: count, Length: 187, dtype: int64
# 24073

# %%
print(df['Passer'].fillna(method='ffill').value_counts())
# df.value_counts()
# Out:
# Passer
# D.Brees         1417
# E.Manning       1329
# T.Brady         1296
# P.Rivers        1290
# M.Stafford      1265
#                 ...
# D.Robinson         1
# M.Koenen           1
# C.Cook             1
# A.Brown            1
# L.Fitzgerald       1
# Name: count, Length: 187, dtype: int64
# C:\Users\User\AppData\Local\Temp\ipykernel_14012\3125964819.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df['Passer'].fillna(method='ffill').value_counts())

# %% [markdown]
# ## men togrisi 40000 mingta ustundan 24000 tasi bosh bolgan ismlar qatorini qanday yol bilan toldirish togri ekanini bilmadim va buning tollari sifattida bir nechtasini keltirib otaman va oxirgisi bu men optimal deb topgan yol boladi va data baza shunday ozgarish bilan davom etadi tepadagi yol ozidan oldingi va keyingi ismlar bilan toldirish usuli

# %%
names = df['Passer'].unique()
names.tolist()
print(df['Passer'].fillna(lambda x: np.random.choice(names) if pd.isna(x) else x))
df['Passer'].value_counts()
# Out:
# 0                                        M.Glennon
# 1        <function <lambda> at 0x0000017E1C3936A0>
# 2        <function <lambda> at 0x0000017E1C3936A0>
# 3                                          D.Kizer
# 4        <function <lambda> at 0x0000017E1C3936A0>
#                            ...
# 40764    <function <lambda> at 0x0000017E1C3936A0>
# 40765    <function <lambda> at 0x0000017E1C3936A0>
# 40766    <function <lambda> at 0x0000017E1C3936A0>
# 40767                                       A.Luck
# 40768                                     A.Dalton
# Name: Passer, Length: 40769, dtype: object
# Passer
# D.Brees         577
# E.Manning       541
# M.Stafford      534
# T.Brady         523
# P.Rivers        514
#                ...
# C.Cook            1
# M.Koenen          1
# A.Brown           1
# L.Fitzgerald      1
# J.Callahan        1
# Name: count, Length: 187, dtype: int64

# %% [markdown]
# ##

# %% [markdown]
# ## uchraydigan ismlarni listga yigib olib NAN qiymatlarni orniga random orqali tanlatish usuli

# %%
df['Passer'] = df['Passer'].fillna(value='Not Given')
df['Passer'].value_counts()
# Out:
# Passer
# Not Given       24073
# D.Brees           577
# E.Manning         541
# M.Stafford        534
# T.Brady           523
#                 ...
# C.Cook              1
# M.Koenen            1
# A.Brown             1
# L.Fitzgerald        1
# J.Callahan          1
# Name: count, Length: 188, dtype: int64

# %% [markdown]
# ## men shu yolni tanladim sababi buncha malumotlarni ozimizning random yoki boshqa yo bila toldirishimiz katta xatoga olib keladi deb oylayman garchi bu ismlar bolsa ham men ularni shunday yol bilan toldirish yaxshiroq deb oylayman

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# FieldGoalDistance              39867
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# FieldGoalResult                39861
# DefTeamScore                    2750
# Tackler2                       35826
# Away_WP_pre                     2546
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                          27
# Passer                             0
# Touchdown                          0
# TwoPointConv                       0
# PassOutcome                        0
# PlayTimeDiff                       0
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# ...

# %% [markdown]
# ## ozgarishni tekshirish uchun

# %%
print(df['Away_WP_pre'].isnull().sum())
print(df['Away_WP_pre'].value_counts())
print(df['Away_WP_pre'].mean())
print(df['Away_WP_pre'].median())
print(df['Away_WP_pre'])
print(df['Away_WP_pre'].std())
# Out:
# 2546
# Away_WP_pre
# 0.514325    141
# 0.485675    126
# 0.000000    116
# 1.000000    103
# 0.499993     45
#            ...
# 0.163670      1
# 0.139549      1
# 0.467202      1
# 0.773475      1
# 0.000254      1
# Name: count, Length: 37264, dtype: int64
# 0.46869555198829244
# 0.471362239854573
# 0        0.774353
# 1        0.943964
# 2        0.634693
# 3        0.064005
# 4        0.071526
#            ...
# 40764    0.163670
# 40765    0.139549
# 40766    0.467202
# 40767    0.773475
# 40768    0.613732
# Name: Away_WP_pre, Length: 40769, dtype: float64
# 0.2857741835257317

# %% [markdown]
# ## men bu ustunni ozini va mediana , avg va valuelari sonini kordim tahlil uchun

# %%
df['Away_WP_pre'] = df['Away_WP_pre'].fillna(value=df['Away_WP_pre'].median())
print(df['Away_WP_pre'].value_counts())
print(df.isnull().sum())
print(df['Away_WP_pre'].std())
# Out:
# Away_WP_pre
# 0.471362    2547
# 0.514325     141
# 0.485675     126
# 0.000000     116
# 1.000000     103
#             ...
# 0.163670       1
# 0.139549       1
# 0.467202       1
# 0.773475       1
# 0.128579       1
# Name: count, Length: 37264, dtype: int64
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# FieldGoalDistance              39867
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# FieldGoalResult                39861
# DefTeamScore                    2750
# Tackler2                       35826
# Away_WP_pre                        0
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                          27
# Passer                             0
# Touchdown                          0
# ...

# %% [markdown]
# ## 0.27670690295437705 bu son men ortacha qiymatni NAN lar uchunqoyganimda paydo bolgan std tepada esa mediana qoyganimda ozgarishni korishingiz mumkin 0.2857741835257317 bu esa ozgarishdan oldingi std men qilgan ozgarish unga oz miqdorda yaqin bolgani uchun men medianani tanladim

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# FieldGoalDistance              39867
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# FieldGoalResult                39861
# DefTeamScore                    2750
# Tackler2                       35826
# Away_WP_pre                        0
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                          27
# Passer                             0
# Touchdown                          0
# TwoPointConv                       0
# PassOutcome                        0
# PlayTimeDiff                       0
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# ...

# %%
print(df['TimeSecs'].value_counts())
print(df['TimeSecs'].mean())
# df['TimeSecs'].isnull().sum()
df['TimeSecs'].std()
# Out:
# TimeSecs
#  1800.0    508
#  900.0     410
#  2700.0    408
#  3600.0    360
#  120.0     360
#           ...
# -91.0        1
#  3598.0      1
# -407.0       1
# -543.0       1
# -803.0       1
# Name: count, Length: 3825, dtype: int64
# 1699.549874822051
# np.float64(1063.620262887654)

# %% [markdown]
# ## tahlil uchun

# %%
print(df['TimeSecs'].fillna(value=df['TimeSecs'].mean()))
print(df['TimeSecs'].std())
df['TimeSecs'] = df['TimeSecs'].fillna(value=df['TimeSecs'].mean())
print(df['TimeSecs'].value_counts())
print(df['TimeSecs'].std())
df['TimeSecs'].isnull().sum()
# Out:
# 0         939.0
# 1         407.0
# 2        1823.0
# 3         528.0
# 4        2355.0
#           ...
# 40764    2868.0
# 40765    1962.0
# 40766    1856.0
# 40767    1289.0
# 40768    2776.0
# Name: TimeSecs, Length: 40769, dtype: float64
# 1063.620262887654
# TimeSecs
#  1800.0    508
#  900.0     410
#  2700.0    408
#  120.0     360
#  3600.0    360
#           ...
# -155.0       1
# -308.0       1
# -294.0       1
# -169.0       1
# -41.0        1
# Name: count, Length: 3826, dtype: int64
# 1063.2679951347561
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# FieldGoalDistance              39867
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# FieldGoalResult                39861
# DefTeamScore                    2750
# Tackler2                       35826
# Away_WP_pre                        0
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                           0
# Passer                             0
# Touchdown                          0
# TwoPointConv                       0
# PassOutcome                        0
# PlayTimeDiff                       0
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# ...

# %%
df = df.drop(columns='Tackler2')
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# FieldGoalDistance              39867
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# FieldGoalResult                39861
# DefTeamScore                    2750
# Away_WP_pre                        0
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                           0
# Passer                             0
# Touchdown                          0
# TwoPointConv                       0
# PassOutcome                        0
# PlayTimeDiff                       0
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# RunGap                         32008
# ...

# %% [markdown]
# ## Tackler2 columinida 87 foizdan koproq malumotlar yoqligi uchun uni xatoliklar keltirib chiqarmasligi uchun ochirib tashladim

# %%
df = df.drop(columns='FieldGoalResult')
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# FieldGoalDistance              39867
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# DefTeamScore                    2750
# Away_WP_pre                        0
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                           0
# Passer                             0
# Touchdown                          0
# TwoPointConv                       0
# PassOutcome                        0
# PlayTimeDiff                       0
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# RunGap                         32008
# Reception                          0
# ...

# %% [markdown]
# ## FieldGoalResult ustunida 97 foizdan koproq malumot yoq bolgani uchun uni ham yoqotdim

# %%
df = df.drop(columns='FieldGoalDistance')
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# DefTeamScore                    2750
# Away_WP_pre                        0
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                           0
# Passer                             0
# Touchdown                          0
# TwoPointConv                       0
# PassOutcome                        0
# PlayTimeDiff                       0
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# RunGap                         32008
# Reception                          0
# TimeUnder                          0
# ...

# %% [markdown]
# ## FieldGoalDistance ustunida ham 97 foizdaan koproq malumotlar yoq va u ham ochirildi

# %%
df = df.drop(columns='RunGap')
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# DefTeamScore                    2750
# Away_WP_pre                        0
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                           0
# Passer                             0
# Touchdown                          0
# TwoPointConv                       0
# PassOutcome                        0
# PlayTimeDiff                       0
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# Reception                          0
# TimeUnder                          0
# Season                             0
# ...

# %% [markdown]
# ## RunGap ustunida ham 78 foizdan koproq malumotlar yoqligi tufayli ochirildi

# %%
print(df['DefTeamScore'].isnull().sum())
print(df['DefTeamScore'].value_counts())
print(df['DefTeamScore'].mean())
# print(df['DefTeamScore'].min())
# print(df['DefTeamScore'].max())
print(df['DefTeamScore'].std())
print(df['DefTeamScore'].median())
# Out:
# 2750
# DefTeamScore
# 0.0     7779
# 7.0     4508
# 3.0     3545
# 10.0    3287
# 14.0    2159
# 17.0    2113
# 13.0    1851
# 6.0     1650
# 20.0    1444
# 24.0    1063
# 21.0     957
# 16.0     879
# 23.0     779
# 9.0      723
# 27.0     697
# 19.0     479
# 31.0     460
# 28.0     395
# 26.0     329
# 30.0     324
# 12.0     312
# 34.0     281
# 22.0     215
# 33.0     174
# 15.0     170
# 35.0     167
# 38.0     166
# 29.0     134
# 37.0     105
# 41.0      91
# 18.0      80
# 25.0      78
# 36.0      76
# 42.0      73
# 8.0       63
# 32.0      54
# 2.0       51
# 5.0       42
# 40.0      41
# 45.0      40
# 11.0      27
# 39.0      25
# 48.0      24
# 44.0      23
# 43.0      20
# 49.0      14
# 52.0       8
# 46.0       7
# 47.0       6
# 54.0       5
# 1.0        4
# 55.0       4
# 50.0       4
# 51.0       3
# 4.0        3
# 58.0       3
# 59.0       2
# 53.0       1
# 56.0       1
# 61.0       1
# Name: count, dtype: int64
# 11.366316841579211
# 9.90134048283482
# 10.0

# %%
df['DefTeamScore'] = df['DefTeamScore'].fillna(value=df['DefTeamScore'].median())
print(df['DefTeamScore'].isnull().sum())

df['DefTeamScore'].std()
# Out:
# 0
# np.float64(9.567702623348124)

# %% [markdown]
# ## ortacha qiymat qoyganimda 9.561563753208729 shu natija va mediana qoyganimda tepadagi natija chiqdi va std ikkilasini qoyib tekshirganimda mediananiki yaqin bolgani uchun uni qoydim

# %%
df.isna().sum()
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# DefTeamScore                       0
# Away_WP_pre                        0
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                           0
# Passer                             0
# Touchdown                          0
# TwoPointConv                       0
# PassOutcome                        0
# PlayTimeDiff                       0
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# Reception                          0
# TimeUnder                          0
# Season                             0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Safety', 'yacEPA', 'Drive', 'airEPA', 'Field_Goal_Prob',
#        'posteam', 'Penalty.Yards', 'DefTeamScore', 'Away_WP_pre',
#        'Timeout_Indicator', 'ydsnet', 'TimeSecs', 'Passer', 'Touchdown',
#        'TwoPointConv', 'PassOutcome', 'PlayTimeDiff', 'RushAttempt',
#        'Accepted.Penalty', 'qtr', 'AwayTimeouts_Remaining_Post', 'Reception',
#        'TimeUnder', 'Season', 'Opp_Safety_Prob', 'No_Score_Prob',
#        'Challenge.Replay'],
#       dtype='object')

# %%
df.shape
# Out:
# (40769, 28)

# %%
print(df['posteam'].isna().sum())
print(df['posteam'].value_counts())
# Out:
# 2550
# posteam
# DEN    1284
# PHI    1244
# DET    1243
# NO     1233
# BAL    1218
# IND    1218
# NE     1216
# SEA    1211
# KC     1210
# HOU    1209
# ARI    1208
# SF     1207
# WAS    1201
# GB     1198
# DAL    1192
# CIN    1189
# CHI    1188
# BUF    1186
# NYJ    1183
# MIN    1182
# NYG    1181
# OAK    1180
# ATL    1167
# MIA    1160
# TB     1149
# PIT    1147
# TEN    1138
# CAR    1128
# CLE    1117
# SD     1086
# STL     968
# JAC     936
# JAX     272
# LA      255
# LAC     115
# Name: count, dtype: int64

# %%
df['posteam'] = df['posteam'].fillna(value='NOT GIVEN')

# %%
print(df['posteam'].isna().sum())
print(df['posteam'].value_counts())
# Out:
# 0
# posteam
# NOT GIVEN    2550
# DEN          1284
# PHI          1244
# DET          1243
# NO           1233
# IND          1218
# BAL          1218
# NE           1216
# SEA          1211
# KC           1210
# HOU          1209
# ARI          1208
# SF           1207
# WAS          1201
# GB           1198
# DAL          1192
# CIN          1189
# CHI          1188
# BUF          1186
# NYJ          1183
# MIN          1182
# NYG          1181
# OAK          1180
# ATL          1167
# MIA          1160
# TB           1149
# PIT          1147
# TEN          1138
# CAR          1128
# CLE          1117
# SD           1086
# STL           968
# JAC           936
# JAX           272
# LA            255
# LAC           115
# Name: count, dtype: int64

# %% [markdown]
# ## men tepadagi posteam columni ustida qilgan ishlarim shu boldiki yani men yoq bolgan 2550 ta malumot orniga NOT GIVEN deb berib qoydim, nimaga chunki buncha miqdordagi malumotni qaysidir yo bilan qolda toldirish xatoliklarga olib keladi chunki bu ustun bilan grafik qilinganda ular tahlil keskin buzib yuborishi mumkin, Axir bu 2550 ta malumoyt barcha malumotlarning deyarli 1/16 qismini tashkil qiladi

# %%
df.isna().sum()
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                            0
# Penalty.Yards                      0
# DefTeamScore                       0
# Away_WP_pre                        0
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                           0
# Passer                             0
# Touchdown                          0
# TwoPointConv                       0
# PassOutcome                        0
# PlayTimeDiff                       0
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# Reception                          0
# TimeUnder                          0
# Season                             0
# ...

# %%
print(df['airEPA'].value_counts())
print(df['airEPA'].mean())
print(df['airEPA'].median())
print(df['airEPA'].std())
# Out:
# airEPA
#  1.053000    17
#  0.000000     8
#  0.084494     6
#  0.969958     5
# -1.469790     5
#              ..
#  0.754171     1
#  1.418653     1
# -0.107088     1
#  0.980268     1
# -0.825221     1
# Name: count, Length: 15788, dtype: int64
# 0.5223888106338055
# 0.2956190905026767
# 1.399719636710543

# %%
df['airEPA'] = df['airEPA'].fillna(value='-9999')
print(df['airEPA'].value_counts())
# Out:
# airEPA
#  -9999       24894
#  1.053          17
#  0.0             8
#  0.084494        6
# -1.46979         5
#              ...
#  0.754171        1
#  1.418653        1
# -0.107088        1
#  0.980268        1
# -0.103057        1
# Name: count, Length: 15789, dtype: int64

# %% [markdown]
# ## airEPA ustunida berilmagan malumotlar 70 va 80 foizdan oshmagani uchun uni ochirmadim va NAN qiymatlarni yoqotish uchun missing indikator sifatida ustunda uchramaydigan -9999 ni qoyib ketdim

# %%
print(df['yacEPA'].isnull().sum())
print(df['yacEPA'].value_counts())
print(df['yacEPA'].mean())
print(df['yacEPA'].median())
print(df['yacEPA'].std())
# Out:
# 24902
# yacEPA
#  0.000000     2366
# -7.000000       13
# -0.864491        3
# -14.000000       3
# -0.323526        2
#               ...
#  0.775660        1
# -10.853876       1
#  1.704423        1
# -0.485422        1
#  1.075660        1
# Name: count, Length: 13480, dtype: int64
# -0.39613653499874507
# 0.0
# 1.9986634244316326

# %%
df['yacEPA'] = df['yacEPA'].fillna(value='-9999')
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# Safety                          0
# yacEPA                          0
# Drive                           0
# airEPA                          0
# Field_Goal_Prob                21
# posteam                         0
# Penalty.Yards                   0
# DefTeamScore                    0
# Away_WP_pre                     0
# Timeout_Indicator               0
# ydsnet                          0
# TimeSecs                        0
# Passer                          0
# Touchdown                       0
# TwoPointConv                    0
# PassOutcome                     0
# PlayTimeDiff                    0
# RushAttempt                     0
# Accepted.Penalty                0
# qtr                             0
# AwayTimeouts_Remaining_Post     0
# Reception                       0
# TimeUnder                       0
# Season                          0
# Opp_Safety_Prob                 0
# No_Score_Prob                   0
# ...

# %% [markdown]
# ## men yacEPA ustuni boyicha ham shunday hulosaga keldim va unga ham missing indikator sifatida -9999 berib ketdim

# %%
print(df['Field_Goal_Prob'].isnull().sum())
print(df['Field_Goal_Prob'].value_counts())
print(df['Field_Goal_Prob'].mean())
print(df['Field_Goal_Prob'].median())
print(df['Field_Goal_Prob'].std())
# Out:
# 21
# Field_Goal_Prob
# 0.000000    4096
# 0.213700     544
# 0.233081     174
# 0.208219      23
# 0.208102       9
#             ...
# 0.432242       1
# 0.381506       1
# 0.244675       1
# 0.147057       1
# 0.272976       1
# Name: count, Length: 33822, dtype: int64
# 0.24367961032922636
# 0.2306319714387671
# 0.15940004174754327

# %%
df['Field_Goal_Prob'] = df['Field_Goal_Prob'].fillna(value=df['Field_Goal_Prob'].median())

# %% [markdown]
# ## men yoq bolgan 21 malumot orniga ustun medianasini qoyib ketdim

# %%
df.head(60)
# Out:
#     Unnamed: 0  Safety    yacEPA  Drive    airEPA  Field_Goal_Prob    posteam  \
# 0       244485       0  1.240299     18 -0.588101         0.309404         TB
# 1       115340       0     -9999     22     -9999         0.198142        OAK
# 2        68357       0     -9999      8     -9999         0.000000        NYJ
# 3       368377       0   1.07566     24   0.40208         0.258227        CLE
# 4       384684       0     -9999     11     -9999         0.199771        DEN
# 5       277250       0     -9999     20     -9999         0.000000  NOT GIVEN
# 6       398793       0       0.0     20  0.081113         0.272976        SEA
# 7       370285       0       0.0      9 -2.611042         0.395233        LAC
# 8       364538       0  0.477721      1 -0.095133         0.317982        DAL
# 9       229159       0     -9999     15     -9999         0.000000         NO
# 10      357254       0     -9999     20     -9999         0.539731         NE
# ...

# %% [markdown]
# ## Va qarshingizda tayyor bolgan data set
