# %%
url = "https://assets.datacamp.com/production/repositories/2210/datasets/794e0759b73a2d80baa5d8fb88636a47965139d3/college_datav3.csv"

# %% [markdown]
# # Bu yerda menga  kerakli bolgan data basani urli kochirib olingan

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df= pd.read_csv(url)
df.head()
# Out:
#                                 INSTNM    OPEID  REGION  SAT_AVG_ALL  PCTPELL  \
# 0             Alabama A & M University   100200       5        850.0   0.7249
# 1  University of Alabama at Birmingham   105200       5       1147.0   0.3505
# 2                   Amridge University  2503400       5          NaN   0.7455
# 3  University of Alabama in Huntsville   105500       5       1221.0   0.3179
# 4             Alabama State University   100500       5        844.0   0.7567
#
#    PCTFLOAN  ADM_RATE_ALL       UG  AVGFACSAL COMPL_RPY_5YR_RT  ... CONTROL  \
# 0    0.8159      0.653841   4380.0     7017.0      0.477631579  ...       1
# 1    0.5218      0.604275  10331.0    10221.0      0.673230442  ...       1
# 2    0.8781           NaN     98.0     3217.0      0.636363636  ...       2
# 3    0.4589      0.811971   5220.0     9514.0      0.762222222  ...       1
# 4    0.7692      0.463858   4348.0     7940.0       0.43006993  ...       1
#
# ...

# %% [markdown]
# # Tepada ozimga kerakli kutubhonalarni chaqirib oldim va urlini olgan kutubxonamni dataframe korinishiga keltirib oldim va head orqali bazzi joylarini koz orqali tekshirdim

# %%
sns.set_style('white')
sns.displot(df['Tuition'])

# %% [markdown]
# ## Bu esa displot orqali tuitoin yani oqish narxi desak boladi oshani count qilingani default holatda

# %%
sns.set(color_codes=True)
sns.displot(df['Tuition'],color='k')

# %% [markdown]
# ## bu yerda yana displotni ichidagi color funksiyasi orqali uning rangini ozgartirib olidk

# %%
fig,ax = plt.subplots()
sns.histplot(df['Tuition'],ax=ax)
ax.set(xlabel="Tuition",ylabel="count",xlim=(0,50000),title="Tuition of stats university")
# Out:
# [Text(0.5, 0, 'Tuition'),
#  Text(0, 0.5, 'count'),
#  (0.0, 50000.0),
#  Text(0.5, 1.0, 'Tuition of stats university')]

# %% [markdown]
# ## Tepada set orqali uning x va y labellariga nom kiritdik va tituliga ham nima ekanini yozib qoydik eng asosiy yangi ishimiz bu xlim orqali ozimizga keraak bolgan qismini ajratib oldik yani 0 dan 50000 gacha

# %%
fig, (ax0,ax1) = plt.subplots(nrows=1,ncols=2,sharey=True,figsize=(9,5))

sns.histplot(df['Tuition'],stat='density',ax=ax0)

sns.histplot(df.query('REGION== 5')['Tuition'],stat='density',ax=ax1)

ax1.set(xlabel='Tuition (5)',xlim=(0,70000))
ax1.axvline(x=20000,label="MY BUDGET",linestyle='--')
ax1.legend()

# %% [markdown]
# ## Bu yerda  subplots orqali fig va ikki dona ax yaratib oldik hamda  birinchi ax ni seaborn bilan statga densityni chaqirdik ikkinchisiga ham shunday qildik lekin uning tuitionga shart berdik qachonki region teng bolsa 5 ga deb unga ham statga densityni chaqirdik. yana qilgan ishimiz ax1 ning x labeeliga nom berib limit qoydik. va oxirida ax1 ga MY BUDGET deb label qoshib unga line qoshdik buni ustoz ikkinchi oyda otamiz dedi

# %% [markdown]
# fig, (ax0,ax1) = plt.subplots(nrows=1,ncols=2,sharey=True,figsize=(9,5))
#
# sns.histplot(df['Tuition'],stat='density',ax=ax0)
#
# sns.histplot(df.query('REGION== 5')['Tuition'],stat='density',ax=ax1)
#
# ax1.set(xlabel='Tuition (5)',xlim=(0,70000))
# ax1.axvline(x=20000,label="MY BUDGET",linestyle='--')
# ax1.legend()
